# %% [markdown]
# <a href="https://colab.research.google.com/github/negar67/Python/blob/master/HousePricePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Goal: predict house prices using Kaggle dataset ported to Postgres database
# see the Data fields here: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data

#import necessary libraries
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import statsmodels.api as sm
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'houseprices'

# %%
#generate the database engine URL and load the data
engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))
houseprice_df = pd.read_sql_query('select * from houseprices', con=engine)

engine.dispose()

houseprice_df.head()
# Out:
#    id  mssubclass mszoning  ...  saletype  salecondition saleprice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
#we have some Null values and some non-numerical variables, I need to convert them to numerical
houseprice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1460 non-null   int64
#  1   mssubclass     1460 non-null   int64
#  2   mszoning       1460 non-null   object
#  3   lotfrontage    1201 non-null   float64
#  4   lotarea        1460 non-null   int64
#  5   street         1460 non-null   object
#  6   alley          91 non-null     object
#  7   lotshape       1460 non-null   object
#  8   landcontour    1460 non-null   object
#  9   utilities      1460 non-null   object
#  10  lotconfig      1460 non-null   object
#  11  landslope      1460 non-null   object
#  12  neighborhood   1460 non-null   object
#  13  condition1     1460 non-null   object
#  14  condition2     1460 non-null   object
#  15  bldgtype       1460 non-null   object
#  16  housestyle     1460 non-null   object
# ...

# %%
houseprice_df.describe()
# Out:
#                 id   mssubclass  ...       yrsold      saleprice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
#I want to see which columns are non-numeric 
non_numeric_columns = houseprice_df.select_dtypes(['object']).columns
print(non_numeric_columns)
print("The dataset has {} non-numerical columns".format(len(non_numeric_columns)))
# Out:
# Index(['mszoning', 'street', 'alley', 'lotshape', 'landcontour', 'utilities',
#        'lotconfig', 'landslope', 'neighborhood', 'condition1', 'condition2',
#        'bldgtype', 'housestyle', 'roofstyle', 'roofmatl', 'exterior1st',
#        'exterior2nd', 'masvnrtype', 'exterqual', 'extercond', 'foundation',
#        'bsmtqual', 'bsmtcond', 'bsmtexposure', 'bsmtfintype1', 'bsmtfintype2',
#        'heating', 'heatingqc', 'centralair', 'electrical', 'kitchenqual',
#        'functional', 'fireplacequ', 'garagetype', 'garagefinish', 'garagequal',
#        'garagecond', 'paveddrive', 'poolqc', 'fence', 'miscfeature',
#        'saletype', 'salecondition'],
#       dtype='object')
# The dataset has 43 non-numerical columns

# %%
#I want to see which columns are numerical
numeric_columns = houseprice_df.select_dtypes(['int64','float64']).columns
print(numeric_columns)
print("The dataset has {} numerical columns".format(len(numeric_columns)))
# Out:
# Index(['id', 'mssubclass', 'lotfrontage', 'lotarea', 'overallqual',
#        'overallcond', 'yearbuilt', 'yearremodadd', 'masvnrarea', 'bsmtfinsf1',
#        'bsmtfinsf2', 'bsmtunfsf', 'totalbsmtsf', 'firstflrsf', 'secondflrsf',
#        'lowqualfinsf', 'grlivarea', 'bsmtfullbath', 'bsmthalfbath', 'fullbath',
#        'halfbath', 'bedroomabvgr', 'kitchenabvgr', 'totrmsabvgrd',
#        'fireplaces', 'garageyrblt', 'garagecars', 'garagearea', 'wooddecksf',
#        'openporchsf', 'enclosedporch', 'threessnporch', 'screenporch',
#        'poolarea', 'miscval', 'mosold', 'yrsold', 'saleprice'],
#       dtype='object')
# The dataset has 38 numerical columns

# %%
#handling missing data;I want to see which columns have missing data values
#19 columns have missing values. In this model, I will not use any of these as a feature, therefore, I do nothing about missing values
total_missingvalues = houseprice_df.isnull().sum().sort_values(ascending=False)
percent_missingvalues = (houseprice_df.isnull().sum()/houseprice_df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total_missingvalues, percent_missingvalues], axis = 1, keys=['Total','Percent'])
missing_data.head(25)
# Out:
#               Total   Percent
# poolqc         1453  0.995205
# miscfeature    1406  0.963014
# alley          1369  0.937671
# fence          1179  0.807534
# fireplacequ     690  0.472603
# lotfrontage     259  0.177397
# garagecond       81  0.055479
# garagetype       81  0.055479
# garageyrblt      81  0.055479
# garagefinish     81  0.055479
# garagequal       81  0.055479
# bsmtexposure     38  0.026027
# bsmtfintype2     38  0.026027
# bsmtfintype1     37  0.025342
# bsmtcond         37  0.025342
# bsmtqual         37  0.025342
# masvnrarea        8  0.005479
# masvnrtype        8  0.005479
# electrical        1  0.000685
# utilities         0  0.000000
# yearremodadd      0  0.000000
# mssubclass        0  0.000000
# foundation        0  0.000000
# extercond         0  0.000000
# exterqual         0  0.000000

# %%
#Exploratory Data Analysis
#see the distribution of the target variable; seems to be non-normally distributed
plt.hist(houseprice_df.saleprice)
plt.title("The distribution of house prices")
plt.xlabel("saleprice")
plt.ylabel("number of occurrence")
plt.show()

# %%
#Now, I want to select features
#first, I will derive the correlations of the columns with target variable (for numerical columns only)
#Then, I'll choose 5 numerical variables with highest correlations with saleprice
np.abs(houseprice_df[numeric_columns].iloc[:,1:].corr().loc[:,"saleprice"]).sort_values(ascending=False)
# Out:
# saleprice        1.000000
# overallqual      0.790982
# grlivarea        0.708624
# garagecars       0.640409
# garagearea       0.623431
# totalbsmtsf      0.613581
# firstflrsf       0.605852
# fullbath         0.560664
# totrmsabvgrd     0.533723
# yearbuilt        0.522897
# yearremodadd     0.507101
# garageyrblt      0.486362
# masvnrarea       0.477493
# fireplaces       0.466929
# bsmtfinsf1       0.386420
# lotfrontage      0.351799
# wooddecksf       0.324413
# secondflrsf      0.319334
# openporchsf      0.315856
# halfbath         0.284108
# lotarea          0.263843
# bsmtfullbath     0.227122
# bsmtunfsf        0.214479
# bedroomabvgr     0.168213
# kitchenabvgr     0.135907
# enclosedporch    0.128578
# screenporch      0.111447
# poolarea         0.092404
# mssubclass       0.084284
# overallcond      0.077856
# mosold           0.046432
# threessnporch    0.044584
# yrsold           0.028923
# lowqualfinsf     0.025606
# miscval          0.021190
# ...

# %%
#For selecting features among non-numerical columns, I need to understand their relationship with the target "saleprice"
#So, I'll plot each one against saleprice; I have 43 non-numerical columns
# The ones that show some variance versus saleprice, can be chosen as features; 
#here, I will choose 2 features :mszoning(general zoning classification), street(type of road access)
plt.figure(figsize=(30,50))

for index, column in enumerate(non_numeric_columns): 
  #enumerate(iterable) is a method that adds a counter to an iterable
  plt.subplot(11,4,index+1)
  plt.bar(houseprice_df.groupby(column)["saleprice"].mean().index, houseprice_df.groupby(column)["saleprice"].mean(), color=("grey", "blue"))
  plt.title("Avg saleprice with respect to {}".format(column))
  plt.ylabel("Average saleprice")
  plt.xlabel(column)
  plt.xticks(rotation='vertical')

plt.tight_layout()
plt.show()

# %%
#I need to convert non-numerical features to dummy variables and make a list of dummy-column-names
houseprice_df = pd.concat([houseprice_df,pd.get_dummies(houseprice_df.mszoning, prefix="mszoning", drop_first=True)], axis=1)
houseprice_df.head()
# Out:
#    id  mssubclass mszoning  ...  mszoning_RH  mszoning_RL mszoning_RM
# 0   1          60       RL  ...            0            1           0
# 1   2          20       RL  ...            0            1           0
# 2   3          60       RL  ...            0            1           0
# 3   4          70       RL  ...            0            1           0
# 4   5          60       RL  ...            0            1           0
#
# [5 rows x 85 columns]

# %%
houseprice_df = pd.concat([houseprice_df,pd.get_dummies(houseprice_df.street, prefix="street", drop_first=True)], axis=1)
houseprice_df.head()
# Out:
#    id  mssubclass mszoning  ...  mszoning_RL  mszoning_RM street_Pave
# 0   1          60       RL  ...            1            0           1
# 1   2          20       RL  ...            1            0           1
# 2   3          60       RL  ...            1            0           1
# 3   4          70       RL  ...            1            0           1
# 4   5          60       RL  ...            1            0           1
#
# [5 rows x 86 columns]

# %%
dummy_column_names = list(pd.get_dummies(houseprice_df.mszoning, prefix="mszoning", drop_first=True).columns)
dummy_column_names = dummy_column_names + list(pd.get_dummies(houseprice_df.street, prefix="street", drop_first=True).columns)
dummy_column_names
# Out:
# ['mszoning_FV', 'mszoning_RH', 'mszoning_RL', 'mszoning_RM', 'street_Pave']

# %%
#building the Regression model
#X is the feature dataset
#Y is the target

X = houseprice_df[['overallqual', 'grlivarea', 'garagecars', 'garagearea', 'totalbsmtsf'] + dummy_column_names]
Y = houseprice_df.saleprice
X.head()
# Out:
#    overallqual  grlivarea  garagecars  ...  mszoning_RL  mszoning_RM  street_Pave
# 0            7       1710           2  ...            1            0            1
# 1            6       1262           2  ...            1            0            1
# 2            7       1786           2  ...            1            0            1
# 3            7       1717           3  ...            1            0            1
# 4            8       2198           3  ...            1            0            1
#
# [5 rows x 10 columns]

# %%
#It is best practice to add constant to the Regression Model since fit in statsmodel does not add constants
#fit an Ordinary Linear Regression (OLS) model
X = sm.add_constant(X)

results = sm.OLS(Y, X).fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              saleprice   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.767
# Method:                 Least Squares   F-statistic:                     482.0
# Date:                Thu, 09 Apr 2020   Prob (F-statistic):               0.00
# Time:                        10:15:53   Log-Likelihood:                -17475.
# No. Observations:                1460   AIC:                         3.497e+04
# Df Residuals:                    1449   BIC:                         3.503e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.173e+05    1.8e+04     -6.502      0.000   -1.53e+05   -8.19e+04
# ...

# %%
#fit a linear regression
X=houseprice_df[['overallqual', 'grlivarea', 'garagecars', 'garagearea', 'totalbsmtsf'] + dummy_column_names]
lrm = linear_model.LinearRegression()
lrm.fit(X, Y)

#predictions of the linear regression
predictions = lrm.predict(X)

#error term calculation
errors = Y - predictions


#print estimated coefficients and intercept
print(" Coefficients are: ", lrm.coef_)
print(" Intercept is: ", lrm.intercept_)
# Out:
#  Coefficients are:  [2.33265353e+04 4.56343565e+01 1.34501364e+04 1.64082048e+01
#  2.83816393e+01 2.50875137e+04 1.34204564e+04 2.85658560e+04
#  9.04778936e+03 1.51037622e+02]
#  Intercept is:  -117337.72871399377

# %%
#Checking the assumptions of Linear Regression
#Assumption one: linearity of the model in its coefficients; this is met
#All coeffs are constants so theiy have a linear relationship with the target variable

#Assumption two: the error term should be zero on average;this is met
#A constant was included in the model so it will force error terms to be zero on average

#Assumption three: homoscedasticity; this is not met, error is varying
#Is the error variance systematically changing across observatons?
#check by a plot to see how error variance varies
plt.scatter(predictions, errors)
plt.xlabel('Predicted')
plt.ylabel('Errors')
plt.axhline(y=0)
plt.title('Errors vs. Predicted')
plt.show()

# %%
#Check Assumption 3 with tests too: Bartlett and Levene tests
#the null hypothesis for both tests is that the error is homoscedastic

from scipy.stats import bartlett
from scipy.stats import levene

bartlett_stats = bartlett(predictions, errors)
levene_stats = levene(predictions, errors)

print(bartlett_stats)
print(levene_stats)
# Out:
# BartlettResult(statistic=497.7538525921925, pvalue=2.928793917007747e-110)
# LeveneResult(statistic=491.9822037605606, pvalue=7.294345129826136e-101)

# %%
#Assumption four: low multicollinearity
sns.heatmap(X.corr())

# %%
X.corr()
# Out:
#              overallqual  grlivarea  ...  mszoning_RM  street_Pave
# overallqual     1.000000   0.593007  ...    -0.195515     0.058823
# grlivarea       0.593007   1.000000  ...    -0.154239     0.044121
# garagecars      0.600671   0.467247  ...    -0.221834    -0.020025
# garagearea      0.562022   0.468997  ...    -0.235580    -0.047794
# totalbsmtsf     0.537808   0.454868  ...    -0.247379     0.005068
# mszoning_FV     0.171854   0.024275  ...    -0.090435     0.013866
# mszoning_RH    -0.064666  -0.001070  ...    -0.044101     0.006762
# mszoning_RL     0.126972   0.132936  ...    -0.808585     0.045348
# mszoning_RM    -0.195515  -0.154239  ...     1.000000    -0.003127
# street_Pave     0.058823   0.044121  ...    -0.003127     1.000000
#
# [10 rows x 10 columns]

# %%
#Assumption five: error terms should be uncorrelated with one another; this is met
#check by plotting errors
plt.plot(errors)
plt.show()

# %%
#Another way to check for Assumption 4 is by checking autocorrelation
#if correlation of variable with itself is low, errors are uncorrelate
from statsmodels.tsa.stattools import acf

acf_data = acf(errors)

plt.plot(acf_data[1:])
plt.show()

# %%
#Assumption six: features shouldn't be correlated with the errors; this is met,very low correlation 
X['errors'] = errors
X
X.corr()
# Out:
#               overallqual     grlivarea  ...   street_Pave        errors
# overallqual  1.000000e+00  5.930074e-01  ...  5.882319e-02  2.223140e-14
# grlivarea    5.930074e-01  1.000000e+00  ...  4.412134e-02 -6.551013e-15
# garagecars   6.006707e-01  4.672474e-01  ... -2.002463e-02  8.672268e-14
# garagearea   5.620218e-01  4.689975e-01  ... -4.779429e-02  1.039714e-13
# totalbsmtsf  5.378085e-01  4.548682e-01  ...  5.067534e-03 -4.357652e-15
# mszoning_FV  1.718543e-01  2.427526e-02  ...  1.386638e-02  1.777718e-14
# mszoning_RH -6.466554e-02 -1.069804e-03  ...  6.761917e-03 -7.988449e-15
# mszoning_RL  1.269724e-01  1.329356e-01  ...  4.534805e-02  4.645042e-15
# mszoning_RM -1.955152e-01 -1.542391e-01  ... -3.127496e-03 -1.423459e-14
# street_Pave  5.882319e-02  4.412134e-02  ...  1.000000e+00 -1.058596e-14
# errors       2.223140e-14 -6.551013e-15  ... -1.058596e-14  1.000000e+00
#
# [11 rows x 11 columns]

# %%
sns.heatmap(X.corr())
